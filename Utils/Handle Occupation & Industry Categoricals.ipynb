# %%
import pandas as pd
import json

# %%
def read_data():
    data = []
    f = '../Data/occupation_code.txt'
    with open(f) as f_pointer:
        for row in f_pointer.readlines():
            data.append(row.strip('/n'))
    return data

occupation = read_data()

# %%
occupation
# Out:
# ['American Community Survey Occupation Codes\n',
#  '2012-16\tOccupation Name\n',
#  '\n',
#  '0000\t0000\t0000\t0000\tN/A (Less than 16 years old/unemployed who never worked/NILF who last worked more than 5 years ago.)\n',
#  'Management, Business, Science, and Arts Occupations\n',
#  '00101\t0010\t0010\t0010\tChief executives1 and legislators2\n',
#  '00302\n',
#  '0020\t0020\t0020\t0020\tGeneral and operations managers\n',
#  '0040\t0040\t0040\t0040\tAdvertising and promotions managers\n',
#  '0050\t0050\t0050\t0050\tMarketing and sales managers\n',
#  '00601\t00601\t0060\t0060\tPublic relations and fundraising managers \n',
#  '1 Public relations managers\n',
#  '0100\t0100\t0100\t0100\tAdministrative services managers\n',
#  '0110\t0110\t0110\t0110\tComputer and information systems managers\n',
#  '0120\t0120\t0120\t0120\tFinancial managers\n',
#  '01301\t01301\t0135\t0135\tCompensation and benefits managers \n',
#  '1 Human resources managers\n',
# ...
